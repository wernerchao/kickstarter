# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from subprocess import check_output

# %%
df1 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter001.csv")
df2 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter002.csv")
df3 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter003.csv")
df4 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter004.csv")
df5 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter005.csv")
df6 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter006.csv")
df7 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter007.csv")
df8 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter008.csv")
df9 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter009.csv")
df10 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter010.csv")
df11 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter011.csv")
df12 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter012.csv")
df13 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter013.csv")
df14 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter014.csv")
df15 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter015.csv")
df16 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter016.csv")
df17 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter017.csv")
df18 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter018.csv")
df19 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter019.csv")
df20 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter020.csv")
df21 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter021.csv")
df22 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter022.csv")
df23 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter023.csv")
df24 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter024.csv")
df25 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter025.csv")
df26 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter026.csv")
df27 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter027.csv")
df28 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter028.csv")
df29 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter029.csv")
df30 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter030.csv")
df31 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter031.csv")
df32 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter032.csv")
df33 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter033.csv")
df34 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter034.csv")
df35 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter035.csv")
df36 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter036.csv")
df37 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter037.csv")
df38 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter038.csv")
df39 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter039.csv")
df40 = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter040.csv")

frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10,
          df11, df12, df13, df14, df15, df16, df17, df18, df19, df20,
          df21, df22, df23, df24, df25, df26, df27, df28, df29, df30,
          df31, df32, df33, df34, df35, df36, df37, df38, df39, df40]
          
          
#df = pd.read_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter039.csv")

# %%
#data = df
data = pd.concat(frames)

#data
data.dtypes
#data.index
#data.columns
#data.values
#data.describe()

#data.sort_values(by='goal', ascending=False)

#data[data.state isin='live']
#data['state'] = ['live']

#data.to_string(columns=['state'], index=True)
data['state'] = data['state'].astype('str')

#data['state'].to_string()

#data.dtypes
#data['state'].dtypes

#data.groupby(['state']).sum
#data.dtypes

#df1 = data.select_dtypes(include=['object'])

data
# Out:
#               id                                              photo  \
# 0      805221774  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 1      256204218  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2     1243790301  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 3      730397597  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4      466019019  {"small":"https://ksr-ugc.imgix.net/assets/013...
# 5      216787910  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 6     2049708591  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 7      524184659  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 8      224561142  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 9     1620065370  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 10    2018362464  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 11     854277110  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 12    2014351865  {"small":"https://ksr-ugc.imgix.net/assets/011...
# ...

# %%
#data['country'] = data['country'].astype('str')

# %%
#data['coutry_new'] = data['country'].str.split(',') 
#data['location_new'] = data['location'].str.split(',').values
#data['country'] = data.to_string(columns=['country'])
 
#data1 = data[data['location'].str.contains(["Toronto", "TORONTO", "toronto"], na=False)]
#data1 = data[data['country'].str.contains("CA", case=False, na=False)]
data1 = data[data['location'].str.contains("canada", case=False, na=False)]

#data1 = data[data['location'].str.contains("TORONTO", case=False, na=False)]

data1.dtypes
# Out:
# id                          int64
# photo                      object
# name                       object
# blurb                      object
# goal                      float64
# pledged                   float64
# state                      object
# slug                       object
# disable_communication        bool
# country                    object
# currency                   object
# currency_symbol            object
# currency_trailing_code       bool
# deadline                    int64
# state_changed_at            int64
# created_at                  int64
# launched_at                 int64
# staff_pick                   bool
# backers_count               int64
# static_usd_rate           float64
# usd_pledged               float64
# creator                    object
# location                   object
# category                   object
# profile                    object
# spotlight                    bool
# urls                       object
# ...

# %%
data1
# Out:
#               id                                              photo  \
# 51    1280181776  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 96    1731294643  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 118    351289561  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 135   2017627054  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 174   1697396209  {"small":"https://ksr-ugc.imgix.net/assets/015...
# 206   1214535368  {"small":"https://ksr-ugc.imgix.net/assets/015...
# 247   1169500462  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 276   1449961626  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 282     32867024  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 289   1462705425  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 292    609180473  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 317    455015560  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 369   1666646175  {"small":"https://ksr-ugc.imgix.net/assets/011...
# ...

# %%
data2 = data1[data1['state'].str.contains("successful", case=False, na=False)]
data2 = data2[data2['category'].str.contains("technology", case=False, na=False)]

data2.sort(columns=['id', 'name'])
# Out:
# /home/gliu/miniconda2/envs/datapower/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#               id                                              photo  \
# 1032      422207  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 3321     6322170  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1314     6591307  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3187    19570975  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 1268    25085675  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 294     48703079  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 3357    60812632  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3226    71055019  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 578     73960727  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4078    77502678  {"small":"https://ksr-ugc.imgix.net/assets/012...
# ...

# %%
data2 = data2.loc[lambda s: s.pledged > 10000, :]
data2
# Out:
#               id                                              photo  \
# 383   1113630187  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 491   1310337043  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3357    60812632  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3363  2088786626  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3389   160970457  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 3416   262799902  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3478   283943633  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3512  1354607855  {"small":"https://ksr-ugc.imgix.net/assets/014...
# 3647  1878676383  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 222    930328898  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 283   1461573217  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 475    751441237  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 492   1897028933  {"small":"https://ksr-ugc.imgix.net/assets/012...
# ...

# %%
data2 = data2.loc[lambda s: s.pledged / s.goal > 5, :]
data2 = data2.sort(columns=['pledged', 'goal'], ascending = False)
data2
# Out:
# /home/gliu/miniconda2/envs/datapower/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#               id                                              photo  \
# 492   1897028933  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3300  1025701043  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 2736   479853843  {"small":"https://ksr-ugc.imgix.net/assets/014...
# 3492   319307716  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3490  2026411758  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3478   283943633  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1090  1135387466  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 3128  1044761792  {"small":"https://ksr-ugc.imgix.net/assets/013...
# 3209   499817227  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 1168  2056734343  {"small":"https://ksr-ugc.imgix.net/assets/011...
# ...

# %%
data2['location'].values
# Out:
# array([ '{"country":"CA","urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/montreal-ca","location":"https://www.kickstarter.com/locations/montreal-ca"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1487275943.95c525998af888371127c40ef8b0124b75902272&woe_id=3534"}},"name":"Montreal","displayable_name":"Montreal, Canada","short_name":"Montreal, Canada","id":3534,"state":"QC","type":"Town","is_root":false,"slug":"montreal-ca"}',
#        '{"country":"CA","urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/saskatchewan-ca","location":"https://www.kickstarter.com/locations/saskatchewan-ca"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1487284387.d9f37152d96adb5e85d1b5bf113b980aac0c4d4d&woe_id=29373382"}},"name":"Saskatchewan","displayable_name":"Saskatchewan, Canada","short_name":"Saskatchewan, Canada","id":29373382,"state":"MB","type":"Town","is_root":false,"slug":"saskatchewan-ca"}',
# ...

# %%
data2['name'].values
# Out:
# array(['Revols - Premium Quick Custom-Fit Wireless Earphones',
#        'The Peachy Printer - The First $100 3D Printer & Scanner!',
#        'Chronos 1.4 High-speed Camera',
#        'SmartHalo - Turn your bike into a smart bike',
#        "Biopod - World's First Smart Microhabitat",
#        'Thin Ice 2.0: A Next-Gen Weight Loss Clothing Line',
#        'Ubi - The Ubiquitous Computer - Voice-Activated & Always On',
#        'RoVa4D Full Color Blender 3D Printer',
#        'BI V2.0 - A self-replicating, high precision 3D Printer',
#        "Paradise Desk - Everything you've ever wanted in a desk!",
#        'Fibonacci Clock - An open source clock for nerds with style',
#        'RoVa3D : The First 5 Material/Color Liquid Cooled 3D Printer',
#        'qualMeter:Finally a Smart USB Cable/Charger Tester for Dummy',
#        'Interactive LED Beer Pong Table Kit (BPT X5)',
#        'The Prometheus System - Intuitive Multi-Filament 3D Printing',
# ...

# %%
data2['urls'].values
# Out:
# array([ '{"web":{"project":"https://www.kickstarter.com/projects/revols/revols-premium-quick-custom-fit-wireless-earphones?ref=category","rewards":"https://www.kickstarter.com/projects/revols/revols-premium-quick-custom-fit-wireless-earphones/rewards"}}',
#        '{"web":{"project":"https://www.kickstarter.com/projects/117421627/the-peachy-printer-the-first-100-3d-printer-and-sc?ref=category","rewards":"https://www.kickstarter.com/projects/117421627/the-peachy-printer-the-first-100-3d-printer-and-sc/rewards"}}',
#        '{"web":{"project":"https://www.kickstarter.com/projects/1714585446/chronos-14-high-speed-camera?ref=category","rewards":"https://www.kickstarter.com/projects/1714585446/chronos-14-high-speed-camera/rewards"}}',
#        '{"web":{"project":"https://www.kickstarter.com/projects/1106460188/smarthalo-turn-your-bike-into-a-smart-bike?ref=category","rewards":"https://www.kickstarter.com/projects/1106460188/smarthalo-turn-your-bike-into-a-smart-bike/rewards"}}',
# ...

# %%
data2['source_url'].values
# Out:
# array([ 'https://www.kickstarter.com/discover/categories/technology/sound?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/3d%20printing?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/camera%20equipment?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/gadgets?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/gadgets?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/wearables?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/hardware?ref=category_modal&sort=magic',
#        'https://www.kickstarter.com/discover/categories/technology/3d%20printing?ref=category_modal&sort=magic',
# ...

# %%
data2.iloc[:10,].values
# Out:
# array([[1897028933,
# ...

# %%
#data1.iloc[2,]
data1.dtypes
# Out:
# id                          int64
# photo                      object
# name                       object
# blurb                      object
# goal                      float64
# pledged                   float64
# state                      object
# slug                       object
# disable_communication        bool
# country                    object
# currency                   object
# currency_symbol            object
# currency_trailing_code       bool
# deadline                    int64
# state_changed_at            int64
# created_at                  int64
# launched_at                 int64
# staff_pick                   bool
# backers_count               int64
# static_usd_rate           float64
# usd_pledged               float64
# creator                    object
# location                   object
# category                   object
# profile                    object
# spotlight                    bool
# urls                       object
# ...

# %%
data1.to_csv("/home/gliu/Downloads/Kick/Kickstarter_2017-02/Kickstarter_toronto.csv")

# %%
"""
mpl.rcParams['font.size']=12
mpl.rcParams['savefig.dpi']=100
mpl.rcParams['figure.subplot.bottom']=.1
stopwords = set(STOPWORDS)


wordcloud = WordCloud(
                         background_color='white',
                         stopwords=stopwords,
                         max_words=200,
                         max_font_size=40,
                         random_state=42
                         ).generate(str(data['name']))
"""
# Out:
# "\nmpl.rcParams['font.size']=12\nmpl.rcParams['savefig.dpi']=100\nmpl.rcParams['figure.subplot.bottom']=.1\nstopwords = set(STOPWORDS)\n\n\nwordcloud = WordCloud(\n                         background_color='white',\n                         stopwords=stopwords,\n                         max_words=200,\n                         max_font_size=40,\n                         random_state=42\n                         ).generate(str(data['name']))\n"

# %%
"""
print(wordcloud)
fig=plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)

"""
# Out:
# '\nprint(wordcloud)\nfig=plt.figure(1)\nplt.imshow(wordcloud)\nplt.axis(\'off\')\nplt.show()\nfig.savefig("word1.png", dpi=900)\n\n'
